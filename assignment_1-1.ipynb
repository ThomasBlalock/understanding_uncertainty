# %% [markdown]
# # Assignment 1
# ### Understanding Uncertainty
# ### Due 9/5

# %% [markdown]
# 1. Create a new public repo on Github under your account. Include a readme file.
# 2. Clone it to your machine. Put this file into that repo.
# 3. Use the following function to download the example data for the course:

# %%
def download_data(force=False):
    """Download and extract course data from Zenodo."""
    import urllib.request, zipfile, os
    
    zip_path = 'data.zip'
    data_dir = 'data'
    
    if not os.path.exists(zip_path) or force:
        print("Downloading course data")
        urllib.request.urlretrieve(
            'https://zenodo.org/records/16954427/files/data.zip?download=1',
            zip_path
        )
        print("Download complete")
    else:
        print("Download file already exists")
        
    if not os.path.exists(data_dir) or force:
        print("Extracting data files...")
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(data_dir)
        print("Data extracted")
    else:
        print("Data directory already exists")

download_data()
# Out:
# ...
# Download complete
# Extracting data files...
# Data extracted

# %% [markdown]
# 4. Open one of the datasets using Pandas:
#     1. `ames_prices.csv`: Housing characteristics and prices
#     2. `college_completion.csv`: Public, nonprofit, and for-profit educational institutions, graduation rates, and financial aid
#     3. `ForeignGifts_edu.csv`: Monetary and in-kind transfers from foreign entities to U.S. educational institutions
#     4. `iowa.csv`: Liquor sales in Iowa, at the transaction level
#     5. `metabric.csv`: Cancer patient and outcome data
#     6. `mn_police_use_of_force.csv`: Records of physical altercations between Minnessota police and private citizens
#     7. `nhanes_data_17_18.csv`: National Health and Nutrition Examination Survey
#     8. `tuna.csv`: Yellowfin Tuna Genome (I don't recommend this one; it's just a sequence of G, C, A, T )
#     9. `va_procurement.csv`: Public spending by the state of Virginia

# %%
# Open the va_procurement.csv file
import pandas as pd
df = pd.read_csv('data/va_procurement.csv')
df.head()
# Out:
#    Unnamed: 0                                 Entity Description   NIGP #  \
# 0     1209821  Virginia Polytechnic Institute and State Unive...  91577.0
# 1     1511053                      Virginia Department of Energy  20468.0
# 2      410883                Department of Corrections - Academy  38542.0
# 3     1360394                            Old Dominion University  49000.0
# 4     1180847                                Longwood University   5000.0
#
#                                     NIGP Description  \
# 0  Telephone Services, Long Distance and Local (I...
# 1  Peripherals, Miscellaneous: Joy Sticks, Graphi...
# 2             Entrees, Meat (Includes Beef and Pork)
# 3  LABORATORY EQUIPMENT, ACCESSORIES AND SUPPLIES...
# 4                         ART EQUIPMENT AND SUPPLIES
#
#                                     Item Description        Order #  \
# 0                 -10K 14-17' DF IND FORKLIFT0550610  A208_P4426539
# ...

# %% [markdown]
# 5. Pick two or three variables and briefly analyze them
#     - Is it a categorical or numeric variable?
#     - How many missing values are there? (`df['var'].isna()` and `np.sum()`)
#     - If categorical, tabulate the values (`df['var'].value_counts()`) and if numeric, get a summary (`df['var'].describe()`)

# %%
# Analyze variables
cols_to_analyze = ["Procurement Transaction Desc", "Line Total"]
proc_trans_desc_type = df["Procurement Transaction Desc"].dtype
line_total_type = df["Line Total"].dtype
proc_trans_desc_missing_values = df["Procurement Transaction Desc"].isna().sum()
line_total_missing_values = df["Line Total"].isna().sum()

print(f"Procurement Transaction Desc type: {proc_trans_desc_type} - Categorical")
print(f"Line Total type: {line_total_type} - Numberic\n")
print(f"Procurement Transaction Desc missing values: {proc_trans_desc_missing_values}")
print(f"Line Total missing values: {line_total_missing_values}\n")

print(df["Procurement Transaction Desc"].value_counts())
print("\nLine Total Summary:")
print(df["Line Total"].describe())
# Out:
# Procurement Transaction Desc type: object - Categorical
# Line Total type: float64 - Numberic
#
# Procurement Transaction Desc missing values: 0
# Line Total missing values: 0
#
# Procurement Transaction Desc
# IMPORT                                          37398
# Supplies - Non-Technology                       32759
# Non-professional Services - Non-Technology       9514
# Non-Procurement or Other                         6212
# Equipment - Non-Technology                       3035
# Non-professional Services - Technology           1937
# Supplies - Technology                            1710
# Equipment - Technology                           1421
# Professional Services                            1084
# Printing                                          482
# Construction                                      192
# Highway Construction                               90
# Cooperative Procurement                            21
# Real Property                                      16
# ...

# %% [markdown]
# 6. What are some questions and prediction tools you could create using these data? Who would the stakeholder be for that prediction tool? What practical or ethical questions would it create? What other data would you want, that are not available in your data?

# %% [markdown]
# With this data, I could answer the questions:<br>
# * How much is the VA government spending split across different services and projects?
# * What types of services and projects is the VA government prioritizing with its spending?
#
#
# You could use this data to predict how much the VA government would have to spend on projects given their expense category.
# <br><br>
# The stakeholders for this tool would be primarily the VA Governor, the VA General Assembly, public project managers, and VA taxpayers.
# <br><br>
# This tool would create the following practical and ethical questions:<br>
# * Would this tool remain accurate as market conditions and techology change?
# * Might using this tool disincentivize funding important projects that correlate with higher expenses?
#
#
# Other data that would be helpful include:<br>
# * Timestamp - So we can make sure that the model would be resilient outside of immidiate market conditions.
# * Project - Knowing what project an expense contributed to could provide insights into how budgets should be structured and money allocated within the government.

# %% [markdown]
# 7. Commit your work to the repo (`git commit -am 'Finish assignment'` at the command line, or use the Git panel in VS Code). Push your work back to Github and submit the link on Canvas in the assignment tab.
